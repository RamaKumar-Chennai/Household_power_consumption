# %%
#Import the required libraries

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#LOAD THE DATA

# %%
#Read the .txt file and create a dataframe 
data = pd.read_csv("C:\\Users\\Rama Kumar\\Downloads\\household_power_consumption.txt", sep=';',
                   parse_dates={'datetime': ['Date', 'Time']},dayfirst=True,
                   infer_datetime_format=True,
                   na_values='?',
                   low_memory=False)
# Out:
# C:\Users\Rama Kumar\AppData\Local\Temp\ipykernel_4940\3247391351.py:2: FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
#   data = pd.read_csv("C:\\Users\\Rama Kumar\\Downloads\\household_power_consumption.txt", sep=';',
# C:\Users\Rama Kumar\AppData\Local\Temp\ipykernel_4940\3247391351.py:2: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   data = pd.read_csv("C:\\Users\\Rama Kumar\\Downloads\\household_power_consumption.txt", sep=';',

# %% [raw]
#                                         #Know the Data
#                        #Understand the structure ,size and key characteristics of the data.

# %%
data.head()
# Out:
#              datetime  Global_active_power  Global_reactive_power  Voltage  \
# 0 2006-12-16 17:24:00                4.216                  0.418   234.84
# 1 2006-12-16 17:25:00                5.360                  0.436   233.63
# 2 2006-12-16 17:26:00                5.374                  0.498   233.29
# 3 2006-12-16 17:27:00                5.388                  0.502   233.74
# 4 2006-12-16 17:28:00                3.666                  0.528   235.68
#
#    Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3
# 0              18.4             0.0             1.0            17.0
# 1              23.0             0.0             1.0            16.0
# 2              23.0             0.0             2.0            17.0
# 3              23.0             0.0             1.0            17.0
# 4              15.8             0.0             1.0            17.0

# %%
data.tail()
# Out:
#                    datetime  Global_active_power  Global_reactive_power  \
# 2075254 2010-11-26 20:58:00                0.946                    0.0
# 2075255 2010-11-26 20:59:00                0.944                    0.0
# 2075256 2010-11-26 21:00:00                0.938                    0.0
# 2075257 2010-11-26 21:01:00                0.934                    0.0
# 2075258 2010-11-26 21:02:00                0.932                    0.0
#
#          Voltage  Global_intensity  Sub_metering_1  Sub_metering_2  \
# 2075254   240.43               4.0             0.0             0.0
# 2075255   240.00               4.0             0.0             0.0
# 2075256   239.82               3.8             0.0             0.0
# 2075257   239.70               3.8             0.0             0.0
# 2075258   239.55               3.8             0.0             0.0
#
#          Sub_metering_3
# 2075254             0.0
# 2075255             0.0
# 2075256             0.0
# 2075257             0.0
# ...

# %%
data.shape
# Out:
# (2075259, 8)

# %%
#Print the column names and their datatypes 
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075259 entries, 0 to 2075258
# Data columns (total 8 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   datetime               datetime64[ns]
#  1   Global_active_power    float64
#  2   Global_reactive_power  float64
#  3   Voltage                float64
#  4   Global_intensity       float64
#  5   Sub_metering_1         float64
#  6   Sub_metering_2         float64
#  7   Sub_metering_3         float64
# dtypes: datetime64[ns](1), float64(7)
# memory usage: 126.7 MB

# %%
#Print the other parameters like max,min,std values for numeric columns
data.describe()
# Out:
#                             datetime  Global_active_power  \
# count                        2075259         2.049280e+06
# mean   2008-12-06 07:12:59.999994112         1.091615e+00
# min              2006-12-16 17:24:00         7.600000e-02
# 25%              2007-12-12 00:18:30         3.080000e-01
# 50%              2008-12-06 07:13:00         6.020000e-01
# 75%              2009-12-01 14:07:30         1.528000e+00
# max              2010-11-26 21:02:00         1.112200e+01
# std                              NaN         1.057294e+00
#
#        Global_reactive_power       Voltage  Global_intensity  Sub_metering_1  \
# count           2.049280e+06  2.049280e+06      2.049280e+06    2.049280e+06
# mean            1.237145e-01  2.408399e+02      4.627759e+00    1.121923e+00
# min             0.000000e+00  2.232000e+02      2.000000e-01    0.000000e+00
# 25%             4.800000e-02  2.389900e+02      1.400000e+00    0.000000e+00
# ...

# %%
#Check for the null values
data.isnull().sum()
# Out:
# datetime                     0
# Global_active_power      25979
# Global_reactive_power    25979
# Voltage                  25979
# Global_intensity         25979
# Sub_metering_1           25979
# Sub_metering_2           25979
# Sub_metering_3           25979
# dtype: int64

# %%
#Check for duplicates
data.duplicated().sum()
# Out:
# 0

# %%
data.nunique()
# Out:
# datetime                 2075259
# Global_active_power         4186
# Global_reactive_power        532
# Voltage                     2837
# Global_intensity             221
# Sub_metering_1                88
# Sub_metering_2                81
# Sub_metering_3                32
# dtype: int64

# %%
#Unique values in in target  column

data['Global_active_power'].unique()
# Out:
# array([4.216, 5.36 , 5.374, ..., 9.63 , 9.648, 8.6  ])

# %%
#Number of Unique values in in target  column
data['Global_active_power'].nunique()
# Out:
# 4186

# %%
#Frequency of values in a column
data['Global_active_power'].value_counts()
# Out:
# Global_active_power
# 0.218    9565
# 0.216    9363
# 0.322    9350
# 0.324    9304
# 0.326    9187
#          ...
# 7.094       1
# 7.930       1
# 8.274       1
# 8.246       1
# 8.600       1
# Name: count, Length: 4186, dtype: int64

# %%
#Co-relation
corr=data.drop('datetime',axis=1).corr()
plt.figure(figsize=(15, 5))
sns.heatmap(corr, cmap= "coolwarm", annot = True, fmt= ".2f")
plt.show()

#We find that Global_active_power and Global_intensity are highly corelated

# %% [raw]
#                                   Visualize Data Distribution

# %%
# SELECT ONLY NUMERIC COLUMNS
import numpy as np

number_columns=data.select_dtypes(include = [np.number]).columns
number_columns
# Out:
# Index(['Global_active_power', 'Global_reactive_power', 'Voltage',
#        'Global_intensity', 'Sub_metering_1', 'Sub_metering_2',
#        'Sub_metering_3'],
#       dtype='object')

# %%
# Histogram for numerical variables

data[number_columns].hist(bins=50, figsize=(15, 10))
plt.suptitle('Histograms of Numerical Variables')
plt.show()

# %% [raw]
#                                                   Visualize Time Series Data
#                                                    Energy trends

# %%
                             
plt.figure(figsize=(15,5))
plt.plot(data['datetime'],data['Global_active_power'])
         


plt.title("GLOBAL ACTIVE POWER OVER TIME")
plt.xlabel("DATE")
plt.ylabel("GLOBAL ACTIVE POWER(Kilowatts)")
plt.show()

# %% [raw]
#                                                             #Data Cleaning

# %%
                                            #Handle the missing values
data['Global_active_power']=data['Global_active_power'].fillna(data['Global_active_power'].mean())
data['Global_reactive_power']=data['Global_reactive_power'].fillna(data['Global_reactive_power'].mean())
data['Voltage']=data['Voltage'].fillna(data['Voltage'].mean())
data['Global_intensity']=data['Global_intensity'].fillna(data['Global_intensity'].mean())
data['Sub_metering_1']=data['Sub_metering_1'].fillna(data['Sub_metering_1'].mean())
data['Sub_metering_2']=data['Sub_metering_2'].fillna(data['Sub_metering_2'].mean())
data['Sub_metering_3']=data['Sub_metering_3'].fillna(data['Sub_metering_3'].mean())

# %%
#Check for the null values
data.isnull().sum()
# Out:
# datetime                 0
# Global_active_power      0
# Global_reactive_power    0
# Voltage                  0
# Global_intensity         0
# Sub_metering_1           0
# Sub_metering_2           0
# Sub_metering_3           0
# dtype: int64

# %%
# Check for negative values in numerical columns
negative_values = data[number_columns] < 0
print("\nNegative values in numerical columns:\n", negative_values.sum())
# Out:
# Negative values in numerical columns:
#  Global_active_power      0
# Global_reactive_power    0
# Voltage                  0
# Global_intensity         0
# Sub_metering_1           0
# Sub_metering_2           0
# Sub_metering_3           0
# dtype: int64

# %%
#FIND THE OUTLIERS
for i in number_columns:
   plt.figure(figsize=(4, 3))
   sns.boxplot(x=data[i])
   plt.show()

# %%
#FIND THE SKEWNESS VALUES
data.skew(numeric_only=True)
# Out:
# Global_active_power      1.797520
# Global_reactive_power    1.269888
# Voltage                 -0.328729
# Global_intensity         1.860784
# Sub_metering_1           5.982102
# Sub_metering_2           7.135356
# Sub_metering_3           0.729267
# dtype: float64

# %%
#The Interquartile Range (IQR) method identifies anomalies by calculating the range between the first quartile (Q1) and the third quartile (Q3).
# Calculate IQR

for i in number_columns:
  Q1 = data[i].quantile(0.25)
  Q3 = data[i].quantile(0.75)
  IQR = Q3 - Q1
  LB=Q1 - 1.5 * IQR
  UB=Q3 + 1.5 * IQR
  data.loc[data[i]<LB,i]=LB
  data.loc[data[i]>UB,i]=UB

# %%
for i in number_columns:
   plt.figure(figsize=(4, 3))
   sns.boxplot(x=data[i])
   plt.show()

# %%
data.skew(numeric_only=True)
#the skewness after IQR CAPPING
# Out:
# Global_active_power      1.051001
# Global_reactive_power    0.817568
# Voltage                 -0.183980
# Global_intensity         1.060911
# Sub_metering_1           0.000000
# Sub_metering_2           1.473784
# Sub_metering_3           0.729267
# dtype: float64

# %% [raw]
# """ before IQR capping,skewness was
#
#
# Global_active_power      1.797520
# Global_reactive_power    1.269888
# Voltage                 -0.328729
# Global_intensity         1.860784
# Sub_metering_1           5.982102
# Sub_metering_2           7.135356
# Sub_metering_3           0.729267
# dtype: float64
#
#
# """

# %% [raw]
#                        #FINDING THE ANOMALY FOR THE GLOBAL ACTIVE POWER

# %%
data['anomaly'] = data['Global_active_power'].apply(lambda x: x < LB or x > UB)

# %%
data
# Out:
#                    datetime  Global_active_power  Global_reactive_power  \
# 0       2006-12-16 17:24:00                3.335                  0.408
# 1       2006-12-16 17:25:00                3.335                  0.408
# 2       2006-12-16 17:26:00                3.335                  0.408
# 3       2006-12-16 17:27:00                3.335                  0.408
# 4       2006-12-16 17:28:00                3.335                  0.408
# ...                     ...                  ...                    ...
# 2075254 2010-11-26 20:58:00                0.946                  0.000
# 2075255 2010-11-26 20:59:00                0.944                  0.000
# 2075256 2010-11-26 21:00:00                0.938                  0.000
# 2075257 2010-11-26 21:01:00                0.934                  0.000
# 2075258 2010-11-26 21:02:00                0.932                  0.000
#
#          Voltage  Global_intensity  Sub_metering_1  Sub_metering_2  \
# ...

# %%
data.loc[data['anomaly']==True,:]
# Out:
# Empty DataFrame
# Columns: [datetime, Global_active_power, Global_reactive_power, Voltage, Global_intensity, Sub_metering_1, Sub_metering_2, Sub_metering_3, anomaly]
# Index: []

# %% [raw]
#                               #It is clear that there is no anomaly in the Global_active_power column

# %% [raw]
#       # Create additional features such as date,daily average

# %%
data.insert(1,'Date',None)
data['Date']=data['datetime'].dt.date
data['Date']=pd.to_datetime(data['Date'])
data.head()
# Out:
#              datetime       Date  Global_active_power  Global_reactive_power  \
# 0 2006-12-16 17:24:00 2006-12-16                3.335                  0.408
# 1 2006-12-16 17:25:00 2006-12-16                3.335                  0.408
# 2 2006-12-16 17:26:00 2006-12-16                3.335                  0.408
# 3 2006-12-16 17:27:00 2006-12-16                3.335                  0.408
# 4 2006-12-16 17:28:00 2006-12-16                3.335                  0.408
#
#    Voltage  Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3  \
# 0   234.84              13.9             0.0             1.0            17.0
# 1   233.63              13.9             0.0             1.0            16.0
# 2   233.29              13.9             0.0             2.0            17.0
# 3   233.74              13.9             0.0             1.0            17.0
# 4   235.68              13.9             0.0             1.0            17.0
#
#    anomaly
# 0    False
# 1    False
# ...

# %%
                          
Daily_Average=data.groupby('Date')['Global_active_power'].mean() 
Daily_Average=Daily_Average.reset_index()
Daily_Average.columns=['Date','Daily_average']
merged_data=pd.merge(data,Daily_Average,on='Date',how='inner')
merged_data
# Out:
#                    datetime       Date  Global_active_power  \
# 0       2006-12-16 17:24:00 2006-12-16                3.335
# 1       2006-12-16 17:25:00 2006-12-16                3.335
# 2       2006-12-16 17:26:00 2006-12-16                3.335
# 3       2006-12-16 17:27:00 2006-12-16                3.335
# 4       2006-12-16 17:28:00 2006-12-16                3.335
# ...                     ...        ...                  ...
# 2075254 2010-11-26 20:58:00 2010-11-26                0.946
# 2075255 2010-11-26 20:59:00 2010-11-26                0.944
# 2075256 2010-11-26 21:00:00 2010-11-26                0.938
# 2075257 2010-11-26 21:01:00 2010-11-26                0.934
# 2075258 2010-11-26 21:02:00 2010-11-26                0.932
#
#          Global_reactive_power  Voltage  Global_intensity  Sub_metering_1  \
# 0                        0.408   234.84              13.9             0.0
# 1                        0.408   233.63              13.9             0.0
# ...

# %%
# Create new features: day of the week, month,day,year and Hour
merged_data['Year']=merged_data['datetime'].dt.year
merged_data['Month']=merged_data['datetime'].dt.month
merged_data['Day']=merged_data['datetime'].dt.day
merged_data['Day_of_Week']=merged_data['datetime'].dt.dayofweek
merged_data['Hour']=merged_data['datetime'].dt.hour

merged_data
# Out:
#                    datetime       Date  Global_active_power  \
# 0       2006-12-16 17:24:00 2006-12-16                3.335
# 1       2006-12-16 17:25:00 2006-12-16                3.335
# 2       2006-12-16 17:26:00 2006-12-16                3.335
# 3       2006-12-16 17:27:00 2006-12-16                3.335
# 4       2006-12-16 17:28:00 2006-12-16                3.335
# ...                     ...        ...                  ...
# 2075254 2010-11-26 20:58:00 2010-11-26                0.946
# 2075255 2010-11-26 20:59:00 2010-11-26                0.944
# 2075256 2010-11-26 21:00:00 2010-11-26                0.938
# 2075257 2010-11-26 21:01:00 2010-11-26                0.934
# 2075258 2010-11-26 21:02:00 2010-11-26                0.932
#
#          Global_reactive_power  Voltage  Global_intensity  Sub_metering_1  \
# 0                        0.408   234.84              13.9             0.0
# 1                        0.408   233.63              13.9             0.0
# ...

# %%
# Create a feature for season
def get_season(month):
    if month in [12, 1, 2]:
        return 'Winter'
    elif month in [3, 4, 5]:
        return 'Spring'
    elif month in [6, 7, 8]:
        return 'Summer'
    else:
        return 'Fall'

merged_data['Season'] = merged_data['Month'].apply(get_season)

# Display the first few rows to verify the new features
merged_data.head()
# Out:
#              datetime       Date  Global_active_power  Global_reactive_power  \
# 0 2006-12-16 17:24:00 2006-12-16                3.335                  0.408
# 1 2006-12-16 17:25:00 2006-12-16                3.335                  0.408
# 2 2006-12-16 17:26:00 2006-12-16                3.335                  0.408
# 3 2006-12-16 17:27:00 2006-12-16                3.335                  0.408
# 4 2006-12-16 17:28:00 2006-12-16                3.335                  0.408
#
#    Voltage  Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3  \
# 0   234.84              13.9             0.0             1.0            17.0
# 1   233.63              13.9             0.0             1.0            16.0
# 2   233.29              13.9             0.0             2.0            17.0
# 3   233.74              13.9             0.0             1.0            17.0
# 4   235.68              13.9             0.0             1.0            17.0
#
# ...

# %%
#FIND THE ROLLING MEAN FOR THREE HOURS

# %%
merged_data["Rolling_mean_3hr"]=merged_data['Global_active_power'].rolling(window=10800).mean()

# %%
merged_data.dropna(inplace=True)

# %%
merged_data
# Out:
#                    datetime       Date  Global_active_power  \
# 10799   2006-12-24 05:23:00 2006-12-24                1.666
# 10800   2006-12-24 05:24:00 2006-12-24                0.920
# 10801   2006-12-24 05:25:00 2006-12-24                2.392
# 10802   2006-12-24 05:26:00 2006-12-24                1.202
# 10803   2006-12-24 05:27:00 2006-12-24                1.394
# ...                     ...        ...                  ...
# 2075254 2010-11-26 20:58:00 2010-11-26                0.946
# 2075255 2010-11-26 20:59:00 2010-11-26                0.944
# 2075256 2010-11-26 21:00:00 2010-11-26                0.938
# 2075257 2010-11-26 21:01:00 2010-11-26                0.934
# 2075258 2010-11-26 21:02:00 2010-11-26                0.932
#
#          Global_reactive_power  Voltage  Global_intensity  Sub_metering_1  \
# 10799                    0.124   246.05               8.0             0.0
# 10800                    0.136   247.30               5.4             0.0
# ...

# %%
merged_data.set_index('datetime', inplace=True)

# %%
# Aggregate data to hourly mean value

new_cols1 = ['Year', 'Month', 'Day', 'Day_of_Week', 'Hour','Season','anomaly','Daily_average','Date']
       
df_hourly1 = merged_data.loc[:, ~merged_data.columns.isin(new_cols1)].resample('H').mean()

# Aggregate data to daily mean values
df_daily1 = merged_data.loc[:, ~merged_data.columns.isin(new_cols1)].resample('D').mean()

# Display the first few rows of the aggregated data-hourly
df_hourly1.head()
# Out:
# C:\Users\Rama Kumar\AppData\Local\Temp\ipykernel_4940\1100187860.py:5: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   df_hourly1 = merged_data.loc[:, ~merged_data.columns.isin(new_cols1)].resample('H').mean()
#                      Global_active_power  Global_reactive_power     Voltage  \
# datetime
# 2006-12-24 05:00:00             1.560378               0.050108  245.805135
# 2006-12-24 06:00:00             1.893167               0.050667  245.590833
# 2006-12-24 07:00:00             1.476400               0.099667  242.795333
# 2006-12-24 08:00:00             1.427767               0.052267  241.698667
# 2006-12-24 09:00:00             2.556283               0.093900  239.889833
#
#                      Global_intensity  Sub_metering_1  Sub_metering_2  \
# datetime
# 2006-12-24 05:00:00          7.275676             0.0        0.000000
# 2006-12-24 06:00:00          8.445000             0.0        0.000000
# ...

# %%
# Display the first few rows of the aggregated data-hourly
df_daily1.head()
# Out:
#             Global_active_power  Global_reactive_power     Voltage  \
# datetime
# 2006-12-24             1.487995               0.109021  241.315837
# 2006-12-25             1.716758               0.162921  243.364187
# 2006-12-26             2.559387               0.112358  241.625097
# 2006-12-27             1.056001               0.123979  243.665653
# 2006-12-28             1.313399               0.142564  243.220222
#
#             Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3  \
# datetime
# 2006-12-24          6.371173             0.0        0.685318        4.101164
# 2006-12-25          7.140278             0.0        0.367014        4.024306
# 2006-12-26         10.608472             0.0        0.446181       10.402083
# 2006-12-27          4.491806             0.0        0.218056        4.844444
# 2006-12-28          5.535764             0.0        0.424653        6.372222
#
#             Rolling_mean_3hr
# datetime
# 2006-12-24          1.683495
# ...

# %% [raw]
#                                 Exploratory Analysis

# %%
# Average energy consumption by hour
hourly_avg = df_hourly1.groupby(df_hourly1.index.hour)['Global_active_power'].mean()

plt.figure(figsize=(12, 6))
hourly_avg.plot(kind='bar', color='salmon')
plt.title('Average Global Active Power by Hour')
plt.xlabel('Hour of Day')
plt.ylabel('Global Active Power (kilowatt)')
plt.show()

# %%
# Average energy consumption by day of the week

daily_avg = merged_data.groupby('Day_of_Week')['Global_active_power'].mean()

plt.figure(figsize=(12, 6))
daily_avg.plot(kind='bar', color='skyblue')
plt.title('Average Global Active Power by Day of the Week')
plt.xlabel('Day of the Week')
plt.ylabel('Global Active Power (kilowatt)')
plt.xticks(ticks=range(7), labels=['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun'])
plt.show()

# %%
# Average energy consumption by month
monthly_avg =merged_data.groupby('Month')['Global_active_power'].mean()

plt.figure(figsize=(12, 6))
monthly_avg.plot(kind='bar', color='lightgreen')
plt.title('Average Global Active Power by Month')
plt.xlabel('Month')
plt.ylabel('Global Active Power (kilowatt)')
plt.xticks(ticks=range(1, 13), labels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.show()

# %%
# Average energy consumption by season
seasonal_avg = merged_data.groupby('Season')['Global_active_power'].mean()

plt.figure(figsize=(12, 6))
seasonal_avg.plot(kind='bar', color='orange')
plt.title('Average Global Active Power by Season')
plt.xlabel('Season')
plt.ylabel('Global Active Power (kilowatt)')
plt.show()

# %% [raw]
# 1. Peak Consumption Periods:
# * Energy consumption tends to peak during the evening hours, particularly between 7:00 PM - 10:00 PM, indicating higher usage during these times.
# * There is a noticeable drop in energy consumption during the early morning hours, suggesting lower usage during late night and early morning periods.
#
#
# 2. Day of the Week:
# * Energy consumption shows variation based on the day of the week. Consumption is generally higher during weekends (Saturday and Sunday) compared to
# weekdays (Monday to Friday).
# * There is a slight increase in energy consumption on weekdays, peaking on Tueday and Wednesday, and then decreasing towards the weekend.
#
#
# 3. Monthly Consumption:
# * Energy consumption varies by month, with higher consumption during the late fall and winter months (November, December, January, February) and
# lower consumption during the summer months (May, June, July). This pattern is consistent with seasonal changes in energy usage, where heating and
# lighting requirements are higher during colder months.
#
#
# 4. Seasonal Variations:
# * Energy consumption is highest during the winter season, followed by fall, spring, and summer, in that order. This aligns with the seasonal patterns
# observed in monthly consumption, with winter months having higher energy demands due to heating requirements.
# The dataset shows clear patterns in energy consumption based on time of day, day of the week, month, and season, highlighting the importance of
# understanding these trends for effective energy management and resource planning.

# %% [raw]
# #Resetting the Index of the merged_data dataframe

# %%
merged_data.reset_index(inplace=True)

# %%
#Separating the INDEPENDENT AND DEPENDENT COLUMNS
X=merged_data.drop(['Global_active_power','Date','datetime','anomaly','Year','Month','Day','Day_of_Week','Hour','Season'],axis=1)
#X=merged_data.drop(['Global_active_power','Date','datetime','anomaly','Season'],axis=1)
y=merged_data['Global_active_power']

# %%
X
# Out:
#          Global_reactive_power  Voltage  Global_intensity  Sub_metering_1  \
# 0                        0.124   246.05               8.0             0.0
# 1                        0.136   247.30               5.4             0.0
# 2                        0.000   245.63               9.6             0.0
# 3                        0.000   247.05               6.4             0.0
# 4                        0.000   247.60               7.0             0.0
# ...                        ...      ...               ...             ...
# 2064455                  0.000   240.43               4.0             0.0
# 2064456                  0.000   240.00               4.0             0.0
# 2064457                  0.000   239.82               3.8             0.0
# 2064458                  0.000   239.70               3.8             0.0
# 2064459                  0.000   239.55               3.8             0.0
#
#          Sub_metering_2  Sub_metering_3  Daily_average  Rolling_mean_3hr
# ...

# %% [raw]
# #FEATURE SELECTION USING RANDOM FOREST REGRESSOR MODEL

# %%
from sklearn.ensemble import RandomForestRegressor
fs=RandomForestRegressor(random_state=77)
fs
# Out:
# RandomForestRegressor(random_state=77)

# %%
fs.fit(X,y)
# Out:
# RandomForestRegressor(random_state=77)

# %%
fs.feature_importances_
# Out:
# array([5.85677922e-04, 4.64872718e-04, 9.97855192e-01, 0.00000000e+00,
#        6.17672333e-05, 2.30159659e-04, 3.67584973e-04, 4.34745754e-04])

# %%
selected_columns=pd.DataFrame({

    "columns":X.columns,
    "score":fs.feature_importances_
}).sort_values("score",ascending=False).head(6)["columns"].to_list()

# %%
selected_columns
# Out:
# ['Global_intensity',
#  'Global_reactive_power',
#  'Voltage',
#  'Rolling_mean_3hr',
#  'Daily_average',
#  'Sub_metering_3']

# %%
fs_dataframe=pd.DataFrame({

    "columns":X.columns,
    "score":fs.feature_importances_
})

fs_dataframe['final_score']=np.sqrt(fs_dataframe['score']*1000)
fs_dataframe
# Out:
#                  columns     score  final_score
# 0  Global_reactive_power  0.000586     0.765296
# 1                Voltage  0.000465     0.681816
# 2       Global_intensity  0.997855    31.588846
# 3         Sub_metering_1  0.000000     0.000000
# 4         Sub_metering_2  0.000062     0.248530
# 5         Sub_metering_3  0.000230     0.479750
# 6          Daily_average  0.000368     0.606288
# 7       Rolling_mean_3hr  0.000435     0.659353

# %%
# GRAPH TO SHOW THE FEATURE IMPORTANCES SCORE
plt.figure(figsize=(16, 7))

sns.barplot(data = fs_dataframe, x = 'columns',y = 'final_score' )

plt.show()

# %% [raw]
# OF ALL COLUMNS,GLOBAL INTENSITY IS THE HIGHEST CONTRIBUTOR FOR PREDICTING THE TARGET VARIABLE--GLOBAL ACTIVE POWER

# %% [raw]
# #CORELATION AFTER OUTLIER TREATMENT

# %%
#Co-relation
corr=merged_data.drop(['Date','datetime','anomaly','Year','Month','Day','Day_of_Week','Hour','Season'],axis=1).corr()
plt.figure(figsize=(15, 5))
sns.heatmap(corr, cmap= "coolwarm", annot = True, fmt= ".2f")
plt.show()

# %% [raw]
# After outlier treatment,Sub_metering_1 has no corelation with GLOBAL ACTIVE POWER and it looks blank in the CORELATION GRAPH

# %%
from sklearn.model_selection import train_test_split

# %% [raw]
# #Splitting the data into training and test data

# %%
X_train,X_test,y_train,y_test=train_test_split(X[selected_columns],y,test_size=0.2,random_state=77)

# %%
#STANDARD SCALING

# %%
#Scale the data for better model performance
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
X_train_scaled = ss.fit_transform(X_train)
X_test_scaled = ss.fit_transform(X_test)

# %%
X_train_scaled
# Out:
# array([[-0.26985416, -0.01719223,  0.33082111,  0.20883576, -0.00831815,
#         -0.64994975],
#        [-0.74879392,  0.93367034, -0.02653527, -0.50268661, -0.51721912,
#         -0.64994975],
#        [ 1.37982721, -1.15822731,  1.49303417,  1.60044936,  2.49585567,
#         -0.76927682],
#        ...,
#        [-0.42950075,  0.70546333,  0.28574913, -1.79070449, -0.31264964,
#         -0.76927682],
#        [-0.64236286,  0.09691128,  0.6913969 ,  0.90309805,  0.79546534,
#         -0.76927682],
#        [ 0.31551664, -1.15822731,  0.16984977, -0.04633448, -0.51581539,
#          1.37861048]])

# %%
X_train_scaled.shape
# Out:
# (1651568, 6)

# %%
X_test_scaled
# Out:
# array([[ 0.314923  , -0.60511811,  0.01545801,  0.18287053,  0.49903253,
#          1.37724871],
#        [-0.85327961, -0.5100658 , -1.04762106, -0.69948385,  0.26681513,
#         -0.76971449],
#        [-0.48157878, -0.71918088, -0.64294444,  0.74515202, -0.37625678,
#         -0.76971449],
#        ...,
#        [-0.90637973, -1.15642152,  0.72524797, -0.05831216, -0.33618726,
#         -0.76971449],
#        [ 0.84592419, -1.15642152,  0.47152215,  0.50497795,  0.02565531,
#         -0.76971449],
#        [-0.74707937, -0.49105534,  0.87941049,  0.05561744,  0.33570189,
#         -0.65043875]])

# %%
X_test_scaled.shape
# Out:
# (412892, 6)

# %%
#Building the LINEAR REGRESSION MODEL

# %%
from sklearn.linear_model import LinearRegression
model_lr=LinearRegression()
model_lr
# Out:
# LinearRegression()

# %% [raw]
# #FITTING THE LINEAR REGRESSION MODEL

# %%
model_lr.fit(X_train_scaled,y_train)
# Out:
# LinearRegression()

# %%
#PREDICTING THE MODEL PERFORMANCE FOR  TEST DATA


y_pred_test=model_lr.predict(X_test_scaled)

# %%
#VALIDATE THE MODEL for TESTING DATA   BY FINDING THE RMSE AND MAPE
from sklearn.metrics import root_mean_squared_error,mean_absolute_percentage_error,r2_score


# Calculate RMSE by taking the square root of MSE
rmse = root_mean_squared_error(y_test, y_pred_test) 
mae = mean_absolute_percentage_error(y_test, y_pred_test)
r2 = r2_score(y_test, y_pred_test)


print(f"Root_mean_squared_error: {rmse:.6f}")
print(f"Mean_absolute_percentage_error: {mae:.6f}")
print(f"R² Score: {r2:.6f}")
# Out:
# Root_mean_squared_error: 0.038455
# Mean_absolute_percentage_error: 0.044900
# R² Score: 0.998200

# %%
              # ACTUAL/PREDICTED GLOBAL ACTIVE POWER FOR LINEAR REGRESSION MODEL
import numpy as np

plt.figure(figsize=(12,5))

  # Plot 'Actual' in blue and 'Predicted' in red

plt.plot(np.arange(0,200),y_test.values[:200],label="Actual",color="Blue")
plt.plot(np.arange(0,200),y_pred_test[:200],label="Predicted",color="Red")

plt.title("ACTUAL/PREDICTED GLOBAL ACTIVE POWER FOR LINEAR REGRESSION MODEL")
plt.xlabel("System Index")
plt.ylabel("Power(in kilowatts)")
plt.legend()
plt.show()

# %%
df_result = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred_test})

df_result
# Out:
#          Actual  Predicted
# 2061037   1.386   1.359204
# 205990    0.288   0.261071
# 1130654   0.612   0.607100
# 409647    0.206   0.177815
# 1496364   0.264   0.287569
# ...         ...        ...
# 306263    0.194   0.171615
# 578451    3.064   3.093440
# 1832464   0.214   0.244036
# 636022    1.780   1.822657
# 1233240   0.380   0.379561
#
# [412892 rows x 2 columns]

# %% [raw]
#                                 BUILDING THE RANDOM FOREST REGRESSION MODEL

# %%
from sklearn.ensemble import RandomForestRegressor


model_rf = RandomForestRegressor(n_estimators= 300, random_state= 88, max_depth= 10)
model_rf
# Out:
# RandomForestRegressor(max_depth=10, n_estimators=300, random_state=88)

# %%
model_rf.fit(X_train_scaled,y_train)
# Out:
# RandomForestRegressor(max_depth=10, n_estimators=300, random_state=88)

# %%
#PREDICTING THE MODEL PERFORMANCE FOR  TEST DATA


y_pred_test_rf=model_rf.predict(X_test_scaled)

# %%
#VALIDATE THE MODEL for TESTING DATA   BY FINDING THE RMSE AND MAPE
from sklearn.metrics import root_mean_squared_error,mean_absolute_percentage_error,r2_score


# Calculate RMSE by taking the square root of MSE
rmse = root_mean_squared_error(y_test, y_pred_test_rf) 
mae = mean_absolute_percentage_error(y_test, y_pred_test_rf)
r2 = r2_score(y_test, y_pred_test_rf)


print(f"Root_mean_squared_error: {rmse:.6f}")
print(f"Mean_absolute_percentage_error: {mae:.6f}")
print(f"R² Score: {r2:.6f}")
# Out:
# Root_mean_squared_error: 0.033469
# Mean_absolute_percentage_error: 0.030923
# R² Score: 0.998636

# %%
 # ACTUAL/PREDICTED GLOBAL ACTIVE POWER FOR LINEAR REGRESSION MODEL
import numpy as np

plt.figure(figsize=(12,5))

  # Plot 'Actual' in blue and 'Predicted' in red

plt.plot(np.arange(0,200),y_test.values[:200],label="Actual",color="Blue")
plt.plot(np.arange(0,200),y_pred_test_rf[:200],label="Predicted",color="Red")

plt.title("ACTUAL/PREDICTED GLOBAL ACTIVE POWER FOR RANDOM FOREST REGRESSION MODEL")
plt.xlabel("System Index")
plt.ylabel("Power(in kilowatts)")
plt.legend()
plt.show()

# %%
df_result_rf= pd.DataFrame({'Actual': y_test, 'Predicted': y_pred_test_rf})

df_result_rf
# Out:
#          Actual  Predicted
# 2061037   1.386   1.365772
# 205990    0.288   0.279207
# 1130654   0.612   0.607116
# 409647    0.206   0.207391
# 1496364   0.264   0.281344
# ...         ...        ...
# 306263    0.194   0.186501
# 578451    3.064   3.065382
# 1832464   0.214   0.237338
# 636022    1.780   1.808372
# 1233240   0.380   0.370402
#
# [412892 rows x 2 columns]

# %% [raw]
# PERFORMANCE METRICS FOR LINEAR REGRESSION MODEL
#
# Root_mean_squared_error: 0.038455
# Mean_absolute_percentage_error: 0.044900
# R² Score: 0.998200
#
#
#
#
# PERFORMANCE METRICS FOR RANDOM FOREST REGRESSION MODEL
#
# Root_mean_squared_error: 0.033469
# Mean_absolute_percentage_error: 0.030923
# R² Score: 0.998636
#
#
# #The error is reduced in RANDOM FOREST REGRESSION MODEL.So RANDOM FOREST MODEL is better than LINEAR REGRESSION MODEL at this stage.So
# #I will go for hyper parameter tuning.

# %%
param = {

    "n_estimators": [50, 100, 200, 250, 300],
    "max_depth": [None, 4,5,6,7],
    "min_samples_split": [2,3,4,5,6],
    "max_features": [1,2,3,4,5]
    
    
}

# %%
from sklearn.model_selection import  RandomizedSearchCV

rand_search = RandomizedSearchCV(
    estimator=model_rf,
    param_distributions = param,
    cv = 5,
    n_iter= 5
    

)

# %%
rand_search.fit(X_train_scaled,y_train)
# Out:
# RandomizedSearchCV(cv=5,
#                    estimator=RandomForestRegressor(max_depth=10,
#                                                    n_estimators=300,
#                                                    random_state=88),
#                    n_iter=5,
#                    param_distributions={'max_depth': [None, 4, 5, 6, 7],
#                                         'max_features': [1, 2, 3, 4, 5],
#                                         'min_samples_split': [2, 3, 4, 5, 6],
#                                         'n_estimators': [50, 100, 200, 250,
#                                                          300]})

# %%
tuned_model = rand_search.best_estimator_

# %%
rand_search.best_params_
# Out:
# {'n_estimators': 250,
#  'min_samples_split': 5,
#  'max_features': 3,
#  'max_depth': None}

# %%
y_pred_test_rf_tuned=tuned_model.predict(X_test_scaled)

# %%
# Calculate RMSE by taking the square root of MSE
rmse = root_mean_squared_error(y_test, y_pred_test_rf_tuned) 
mae = mean_absolute_percentage_error(y_test, y_pred_test_rf_tuned)
r2 = r2_score(y_test, y_pred_test_rf_tuned)


print(f"Root_mean_squared_error: {rmse:.6f}")
print(f"Mean_absolute_percentage_error: {mae:.6f}")
print(f"R² Score: {r2:.6f}")
# Out:
# Root_mean_squared_error: 0.027386
# Mean_absolute_percentage_error: 0.016199
# R² Score: 0.999087

# %%
              # ACTUAL/PREDICTED GLOBAL ACTIVE POWER FOR RANDOM FOREST REGRESSION MODEL
import numpy as np

plt.figure(figsize=(12,5))

  # Plot 'Actual' in blue and 'Predicted' in red

plt.plot(np.arange(0,200),y_test.values[:200],label="Actual",color="Blue")
plt.plot(np.arange(0,200),y_pred_test_rf_tuned[:200],label="Predicted",color="Red")

plt.title("ACTUAL/PREDICTED GLOBAL ACTIVE POWER FOR RANDOM FOREST REGRESSION MODEL AFTER HYPERPARAMETER TUNING")
plt.xlabel("System Index")
plt.ylabel("Power(in kilowatts)")
plt.legend()
plt.show()

# %%
df_result_rf_tuned= pd.DataFrame({'Actual': y_test, 'Predicted': y_pred_test_rf_tuned})

df_result_rf_tuned
# Out:
#          Actual  Predicted
# 2061037   1.386   1.374940
# 205990    0.288   0.293174
# 1130654   0.612   0.612772
# 409647    0.206   0.205917
# 1496364   0.264   0.285530
# ...         ...        ...
# 306263    0.194   0.191856
# 578451    3.064   3.066133
# 1832464   0.214   0.220787
# 636022    1.780   1.819981
# 1233240   0.380   0.383057
#
# [412892 rows x 2 columns]

# %%
PERFORMANCE METRICS FOR LINEAR REGRESSION MODEL

Root_mean_squared_error: 0.038455
Mean_absolute_percentage_error: 0.044900
R² Score: 0.998200




PERFORMANCE METRICS FOR RANDOM FOREST REGRESSION MODEL

Root_mean_squared_error: 0.033469
Mean_absolute_percentage_error: 0.030923
R² Score: 0.998636



PERFORMANCE METRICS FOR RANDOM FOREST REGRESSION MODEL after RANDOMIZED SEARCH 

Root_mean_squared_error: 0.027386
Mean_absolute_percentage_error: 0.016199
R² Score: 0.999087



Of all three ML models,RANDOM FOREST REGRESSION MODEL with HYPER PARAMETER TUNING(RANDOMIZED SEARCH ) GIVES THE BEST  RESULTS

# %% [raw]
# NEURAL NETWORK MODEL PERFORMANCE METRICS:
#
#
# Root mean squared error is   0.5268588662147522
#
# Mean absolute percentage error is   0.7015218138694763
#
#  R2_score_value is   0.660955011844635

# %%
OF ALL MODELS,RANDOMIZED SEARCH MODEL IS THE BEST MODEL
